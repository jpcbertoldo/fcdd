# %%
# make a cell print all the outputs instead of just the last one
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from pathlib import Path

data_dir = Path("./data")
data_fpath = data_dir / "2022-07-bmvc-report-01-data01-adaptive-loss.csv"

import pandas as pd
df = pd.read_csv(data_fpath) 

def check_df(df):
    print(df.shape)
    print(df.dtypes)
    return df.head(5)

check_df(df)
# Out:
# (455, 12)
# Name                                  object
# supervise_mode                        object
# normal_class_fullqualified            object
# loss                                  object
# loss_empirical_cdf_clip_threshold    float64
# validate/roc-auc-histavg             float64
# validate/avg-precision-histavg       float64
# scheduler_parameters                  object
# normal_class                           int64
# test/roc-auc                         float64
# test/avg-precision                   float64
# mvtec_class_type                      object
# dtype: object
#                      Name              supervise_mode  \
# 0  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
# 1  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
# 2  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
# 3  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
# 4  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
#
#   normal_class_fullqualified                                         loss  \
# 0            mvtec_14_zipper  pixelwise-batch-avg-clip-score-cdf-adaptive
# 1            mvtec_14_zipper  pixelwise-batch-avg-clip-score-cdf-adaptive
# 2            mvtec_14_zipper  pixelwise-batch-avg-clip-score-cdf-adaptive
# 3            mvtec_14_zipper  pixelwise-batch-avg-clip-score-cdf-adaptive
# 4            mvtec_14_zipper  pixelwise-batch-avg-clip-score-cdf-adaptive
#
#    loss_empirical_cdf_clip_threshold  validate/roc-auc-histavg  \
# 0                               0.05                  0.890021
# 1                               0.15                  0.874998
# 2                               0.15                  0.835181
# 3                               0.05                  0.885790
# 4                               0.05                  0.903222
#
#    validate/avg-precision-histavg scheduler_parameters  normal_class  \
# 0                        0.299138             [0.9985]            14
# 1                        0.194596             [0.9985]            14
# 2                        0.208224             [0.9985]            14
# 3                        0.298539             [0.9985]            14
# 4                        0.351732             [0.9985]            14
#
#    test/roc-auc  test/avg-precision mvtec_class_type
# 0      0.874472            0.271487           object
# 1      0.951397            0.431241           object
# 2      0.938531            0.418613           object
# 3      0.873147            0.279015           object
# 4      0.883907            0.295785           object

# %%
data_df = pd.read_csv(data_fpath) 
df = data_df
df["scheduler_parameters"] = df["scheduler_parameters"].apply(lambda x: float(x.lstrip("[").rstrip("]")))
df["scheduler_parameters"] = df["scheduler_parameters"].apply(lambda x: {0.985000: "higher decay", 0.998500: "equiv. decay"}[x])
df["loss_empirical_cdf_clip_threshold"] = df["loss_empirical_cdf_clip_threshold"].apply(lambda x: str(x) if x else "n/a")
df.drop(columns=["Name"], inplace=True)
check_df(df)
# Out:
# (455, 11)
# supervise_mode                        object
# normal_class_fullqualified            object
# loss                                  object
# loss_empirical_cdf_clip_threshold     object
# validate/roc-auc-histavg             float64
# validate/avg-precision-histavg       float64
# scheduler_parameters                  object
# normal_class                           int64
# test/roc-auc                         float64
# test/avg-precision                   float64
# mvtec_class_type                      object
# dtype: object
#                supervise_mode normal_class_fullqualified  \
# 0  synthetic-anomaly-confetti            mvtec_14_zipper
# 1  synthetic-anomaly-confetti            mvtec_14_zipper
# 2  synthetic-anomaly-confetti            mvtec_14_zipper
# 3  synthetic-anomaly-confetti            mvtec_14_zipper
# 4  synthetic-anomaly-confetti            mvtec_14_zipper
#
#                                           loss  \
# 0  pixelwise-batch-avg-clip-score-cdf-adaptive
# 1  pixelwise-batch-avg-clip-score-cdf-adaptive
# 2  pixelwise-batch-avg-clip-score-cdf-adaptive
# 3  pixelwise-batch-avg-clip-score-cdf-adaptive
# 4  pixelwise-batch-avg-clip-score-cdf-adaptive
#
#   loss_empirical_cdf_clip_threshold  validate/roc-auc-histavg  \
# 0                              0.05                  0.890021
# 1                              0.15                  0.874998
# 2                              0.15                  0.835181
# 3                              0.05                  0.885790
# 4                              0.05                  0.903222
#
#    validate/avg-precision-histavg scheduler_parameters  normal_class  \
# 0                        0.299138         equiv. decay            14
# 1                        0.194596         equiv. decay            14
# 2                        0.208224         equiv. decay            14
# 3                        0.298539         equiv. decay            14
# 4                        0.351732         equiv. decay            14
#
#    test/roc-auc  test/avg-precision mvtec_class_type
# 0      0.874472            0.271487           object
# 1      0.951397            0.431241           object
# 2      0.938531            0.418613           object
# 3      0.873147            0.279015           object
# 4      0.883907            0.295785           object

# %%
data_df = df

# %%
from pandas import DataFrame
import pandas as pd
import numpy as np
from scipy.stats import percentileofscore


def get_color_mask_compare_by_line_every_n_cols(pt, n):
        
    assert pt.shape[1] % n == 0, f"pt.shape[1] % n != 0: {pt.shape[1] % n}"

    def get_ordering_signal(subdf: DataFrame) -> DataFrame:
        """at each line, the values are assigned a value from 0 to 1 respecting the ordering, such that 0 is the min and 1 is the max"""
        # it's ok to round up to 3 decimals because i will probably never have more than 1001 values
        # and it makes the table easier to read/debug
        subdf = subdf.apply(
            lambda series: series.apply(lambda x: percentileofscore(np.sort(series.values), x, kind="strict") / 100), 
            axis=1
        )
        # 1/n is the min value of percentileofscore
        return (subdf / (1 / n)).round(decimals=0).astype(int)

    return np.concatenate(
        [   
            get_ordering_signal(pt.iloc[:, i * n:(i + 1) * n]).values
            for i in range(pt.shape[1] // n)
        ],
        axis=1,
    )
    
COLOR_0 = 'background-color: #DC143C55'
COLOR_MIDDLE = 'background-color: #FFFFFF55'
COLOR_1 = 'background-color: #228B2255'
    
def color_from_mask(color_mask: np.ndarray):
    n = color_mask.max() + 1
    print(f"n: {n}")
    assert n > 1, f"n > 1: {n}"
    
    if n == 2:
        def color(_):
            colormap = np.empty_like(color_mask, dtype=object)
            colormap[color_mask == 0] = COLOR_0
            colormap[color_mask == 1] = COLOR_1
            return colormap
        
        return color
    
    elif n == 3:
        def color(_):
            colormap = np.empty_like(color_mask, dtype=object)
            colormap[color_mask == 0] = COLOR_0
            colormap[color_mask == 1] = COLOR_MIDDLE
            colormap[color_mask == 2] = COLOR_1
            return colormap
        
        return color
    else:
        raise NotImplementedError(f"n > 3 is not implemented, found {n}")

# %%
from pandas import DataFrame
import pandas as pd
import numpy as np
from functools import partial

df = data_df.copy()

row_cols = ["mvtec_class_type", "normal_class_fullqualified"]
column_cols = ["supervise_mode", "loss", "loss_empirical_cdf_clip_threshold"]

metrics = {
    "test/avg-precision": ["mean", "std"],
    "validate/avg-precision-histavg": ["mean",],
    # "test/roc-auc": ["mean", "std"],
    # "validate/roc-auc-histavg": ["mean",],
}
metric_cols = [(k, v) for k, list_vals in metrics.items() for v in list_vals]

pt_all_metrics = pd.pivot_table(df, index=row_cols, columns=column_cols, aggfunc=metrics)

# when it's a percentage
pt_all_metrics = 100 * pt_all_metrics

pt_test_avg = pt_all_metrics[("test/avg-precision", "mean")]
# pt_test_avg = pt_all_metrics[("test/roc-auc", "mean")]
pt_test_avg.loc[("", "object mean"), :] = pt_test_avg.loc["object"].mean(axis=0)
pt_test_avg.loc[("", "texture mean"), :] = pt_test_avg.loc["texture"].mean(axis=0)
pt_test_avg.loc[("", "all mean"), :] = pt_test_avg.mean(axis=0)

pt_test_std = pt_all_metrics[("test/avg-precision", "std")]
# pt_test_std = pt_all_metrics[("test/roc-auc", "std")]
pt_test_std.loc[("", "object mean"), :] = pt_test_std.loc["object"].mean(axis=0)
pt_test_std.loc[("", "texture mean"), :] = pt_test_std.loc["texture"].mean(axis=0)
pt_test_std.loc[("", "all mean"), :] = pt_test_std.mean(axis=0)

pt_validate_histmean_avg = pt_all_metrics[("validate/avg-precision-histavg", "mean")]
# pt_validate_histmean_avg = pt_all_metrics[("validate/roc-auc-histavg", "mean")]
pt_validate_histmean_avg.loc[("", "object mean"), :] = pt_validate_histmean_avg.loc["object"].mean(axis=0)
pt_validate_histmean_avg.loc[("", "texture mean"), :] = pt_validate_histmean_avg.loc["texture"].mean(axis=0)
pt_validate_histmean_avg.loc[("", "all mean"), :] = pt_validate_histmean_avg.mean(axis=0)

pt_composed = pt_test_avg.applymap("{:.1f}".format) + " " + pt_test_std.applymap("({:.1f})".format) + " " + pt_validate_histmean_avg.applymap("[{:.1f}]".format)
# Out:
# /tmp/ipykernel_37802/1545779017.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_test_avg.loc[("", "object mean"), :] = pt_test_avg.loc["object"].mean(axis=0)
# /tmp/ipykernel_37802/1545779017.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_test_std.loc[("", "object mean"), :] = pt_test_std.loc["object"].mean(axis=0)
# /tmp/ipykernel_37802/1545779017.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_validate_histmean_avg.loc[("", "object mean"), :] = pt_validate_histmean_avg.loc["object"].mean(axis=0)

# %% [markdown]
# # compare all

# %%
pt_test_avg
# Out:
# supervise_mode                                     real-anomaly  \
# loss                                        pixelwise-batch-avg
# loss_empirical_cdf_clip_threshold                           nan
# mvtec_class_type normal_class_fullqualified
# object           mvtec_00_bottle                      67.296866
#                  mvtec_01_cable                       57.926316
#                  mvtec_02_capsule                     24.723076
#                  mvtec_05_hazelnut                    50.688459
#                  mvtec_07_metal_nut                   86.081452
#                  mvtec_08_pill                        64.765448
#                  mvtec_09_screw                        6.443677
#                  mvtec_11_toothbrush                  15.643008
#                  mvtec_12_transistor                  49.875187
#                  mvtec_14_zipper                      63.199116
# texture          mvtec_03_carpet                      71.568144
#                  mvtec_04_grid                        17.372383
#                  mvtec_06_leather                     38.575850
#                  mvtec_10_tile                        90.276120
#                  mvtec_13_wood                        48.103402
#                  object mean                          48.664261
#                  texture mean                         53.179180
#                  all mean                             50.257761
#
# supervise_mode                                                                           \
# loss                                        pixelwise-batch-avg-clip-score-cdf-adaptive
# loss_empirical_cdf_clip_threshold                                                  0.05
# mvtec_class_type normal_class_fullqualified
# object           mvtec_00_bottle                                              67.252265
#                  mvtec_01_cable                                               57.788507
#                  mvtec_02_capsule                                             16.212461
#                  mvtec_05_hazelnut                                            43.062496
#                  mvtec_07_metal_nut                                           89.395604
#                  mvtec_08_pill                                                55.912012
#                  mvtec_09_screw                                                7.492276
#                  mvtec_11_toothbrush                                          14.930768
#                  mvtec_12_transistor                                          49.535695
#                  mvtec_14_zipper                                              52.486640
# texture          mvtec_03_carpet                                              68.263759
#                  mvtec_04_grid                                                17.234099
#                  mvtec_06_leather                                             36.274395
#                  mvtec_10_tile                                                85.858487
#                  mvtec_13_wood                                                47.562243
#                  object mean                                                  45.406872
#                  texture mean                                                 51.038597
#                  all mean                                                     47.394540
#
# supervise_mode                                          \
# loss
# loss_empirical_cdf_clip_threshold                 0.15
# mvtec_class_type normal_class_fullqualified
# object           mvtec_00_bottle             57.286663
#                  mvtec_01_cable              54.456499
#                  mvtec_02_capsule             7.336214
#                  mvtec_05_hazelnut           30.227097
#                  mvtec_07_metal_nut          85.401965
#                  mvtec_08_pill               59.466016
#                  mvtec_09_screw               1.411936
#                  mvtec_11_toothbrush         11.298064
#                  mvtec_12_transistor         31.949250
#                  mvtec_14_zipper             38.459553
# texture          mvtec_03_carpet             50.821444
#                  mvtec_04_grid               12.805071
#                  mvtec_06_leather            38.231936
#                  mvtec_10_tile               82.341424
#                  mvtec_13_wood               40.772914
#                  object mean                 37.729326
#                  texture mean                44.994558
#                  all mean                    40.293525
#
# supervise_mode                              synthetic-anomaly-confetti  \
# loss                                               pixelwise-batch-avg
# loss_empirical_cdf_clip_threshold                                  nan
# mvtec_class_type normal_class_fullqualified
# object           mvtec_00_bottle                             17.999043
#                  mvtec_01_cable                              53.097742
#                  mvtec_02_capsule                             9.329936
#                  mvtec_05_hazelnut                           13.912693
#                  mvtec_07_metal_nut                          10.354480
#                  mvtec_08_pill                                2.382963
#                  mvtec_09_screw                               0.518473
#                  mvtec_11_toothbrush                          2.644501
#                  mvtec_12_transistor                         30.780801
#                  mvtec_14_zipper                             27.400019
# texture          mvtec_03_carpet                             41.603822
#                  mvtec_04_grid                               13.854279
#                  mvtec_06_leather                            26.093658
#                  mvtec_10_tile                               79.755414
#                  mvtec_13_wood                               46.962021
#                  object mean                                 16.842065
#                  texture mean                                41.653839
#                  all mean                                    25.599162
#
# supervise_mode                                                                           \
# loss                                        pixelwise-batch-avg-clip-score-cdf-adaptive
# loss_empirical_cdf_clip_threshold                                                  0.05
# mvtec_class_type normal_class_fullqualified
# object           mvtec_00_bottle                                              18.802059
#                  mvtec_01_cable                                               55.358678
#                  mvtec_02_capsule                                              9.458715
#                  mvtec_05_hazelnut                                            14.573342
#                  mvtec_07_metal_nut                                           10.567104
#                  mvtec_08_pill                                                 2.469461
#                  mvtec_09_screw                                                0.554883
#                  mvtec_11_toothbrush                                           8.926436
#                  mvtec_12_transistor                                          36.270536
#                  mvtec_14_zipper                                              28.200499
# texture          mvtec_03_carpet                                              40.096112
#                  mvtec_04_grid                                                13.636888
#                  mvtec_06_leather                                             25.697651
#                  mvtec_10_tile                                                78.361501
#                  mvtec_13_wood                                                46.765370
#                  object mean                                                  18.518171
#                  texture mean                                                 40.911505
#                  all mean                                                     26.421701
#
# supervise_mode
# loss
# loss_empirical_cdf_clip_threshold                 0.15
# mvtec_class_type normal_class_fullqualified
# object           mvtec_00_bottle             41.587236
#                  mvtec_01_cable              46.985322
#                  mvtec_02_capsule            11.476008
#                  mvtec_05_hazelnut           22.247266
#                  mvtec_07_metal_nut          17.932336
#                  mvtec_08_pill                2.522700
#                  mvtec_09_screw               0.510587
#                  mvtec_11_toothbrush          3.655794
#                  mvtec_12_transistor         33.849191
#                  mvtec_14_zipper             38.495597
# texture          mvtec_03_carpet             38.814907
#                  mvtec_04_grid               13.586353
#                  mvtec_06_leather            25.216903
#                  mvtec_10_tile               66.355467
#                  mvtec_13_wood               40.421157
#                  object mean                 21.926204
#                  texture mean                36.878957
#                  all mean                    27.203646

# %%
pt = pt_composed.copy()
pt_color_from = pt_test_avg.copy()
color_mask = get_color_mask_compare_by_line_every_n_cols(pt_color_from, n=3)
pt.style.apply(color_from_mask(color_mask), axis=None)
# Out:
# n: 3
# <style type="text/css">
# #T_1af3c_row0_col0, #T_1af3c_row0_col5, #T_1af3c_row1_col0, #T_1af3c_row1_col4, #T_1af3c_row2_col0, #T_1af3c_row2_col5, #T_1af3c_row3_col0, #T_1af3c_row3_col5, #T_1af3c_row4_col1, #T_1af3c_row4_col5, #T_1af3c_row5_col0, #T_1af3c_row5_col5, #T_1af3c_row6_col1, #T_1af3c_row6_col4, #T_1af3c_row7_col0, #T_1af3c_row7_col4, #T_1af3c_row8_col0, #T_1af3c_row8_col4, #T_1af3c_row9_col0, #T_1af3c_row9_col5, #T_1af3c_row10_col0, #T_1af3c_row10_col3, #T_1af3c_row11_col0, #T_1af3c_row11_col3, #T_1af3c_row12_col0, #T_1af3c_row12_col3, #T_1af3c_row13_col0, #T_1af3c_row13_col3, #T_1af3c_row14_col0, #T_1af3c_row14_col3, #T_1af3c_row15_col0, #T_1af3c_row15_col5, #T_1af3c_row16_col0, #T_1af3c_row16_col3, #T_1af3c_row17_col0, #T_1af3c_row17_col5 {
#   background-color: #228B2255;
# }
# #T_1af3c_row0_col1, #T_1af3c_row0_col4, #T_1af3c_row1_col1, #T_1af3c_row1_col3, #T_1af3c_row2_col1, #T_1af3c_row2_col4, #T_1af3c_row3_col1, #T_1af3c_row3_col4, #T_1af3c_row4_col0, #T_1af3c_row4_col4, #T_1af3c_row5_col2, #T_1af3c_row5_col4, #T_1af3c_row6_col0, #T_1af3c_row6_col3, #T_1af3c_row7_col1, #T_1af3c_row7_col5, #T_1af3c_row8_col1, #T_1af3c_row8_col5, #T_1af3c_row9_col1, #T_1af3c_row9_col4, #T_1af3c_row10_col1, #T_1af3c_row10_col4, #T_1af3c_row11_col1, #T_1af3c_row11_col4, #T_1af3c_row12_col2, #T_1af3c_row12_col4, #T_1af3c_row13_col1, #T_1af3c_row13_col4, #T_1af3c_row14_col1, #T_1af3c_row14_col4, #T_1af3c_row15_col1, #T_1af3c_row15_col4, #T_1af3c_row16_col1, #T_1af3c_row16_col4, #T_1af3c_row17_col1, #T_1af3c_row17_col4 {
#   background-color: #FFFFFF55;
# }
# #T_1af3c_row0_col2, #T_1af3c_row0_col3, #T_1af3c_row1_col2, #T_1af3c_row1_col5, #T_1af3c_row2_col2, #T_1af3c_row2_col3, #T_1af3c_row3_col2, #T_1af3c_row3_col3, #T_1af3c_row4_col2, #T_1af3c_row4_col3, #T_1af3c_row5_col1, #T_1af3c_row5_col3, #T_1af3c_row6_col2, #T_1af3c_row6_col5, #T_1af3c_row7_col2, #T_1af3c_row7_col3, #T_1af3c_row8_col2, #T_1af3c_row8_col3, #T_1af3c_row9_col2, #T_1af3c_row9_col3, #T_1af3c_row10_col2, #T_1af3c_row10_col5, #T_1af3c_row11_col2, #T_1af3c_row11_col5, #T_1af3c_row12_col1, #T_1af3c_row12_col5, #T_1af3c_row13_col2, #T_1af3c_row13_col5, #T_1af3c_row14_col2, #T_1af3c_row14_col5, #T_1af3c_row15_col2, #T_1af3c_row15_col3, #T_1af3c_row16_col2, #T_1af3c_row16_col5, #T_1af3c_row17_col2, #T_1af3c_row17_col3 {
#   background-color: #DC143C55;
# }
# </style>
# <table id="T_1af3c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >supervise_mode</th>
#       <th id="T_1af3c_level0_col0" class="col_heading level0 col0" colspan="3">real-anomaly</th>
#       <th id="T_1af3c_level0_col3" class="col_heading level0 col3" colspan="3">synthetic-anomaly-confetti</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >loss</th>
#       <th id="T_1af3c_level1_col0" class="col_heading level1 col0" >pixelwise-batch-avg</th>
#       <th id="T_1af3c_level1_col1" class="col_heading level1 col1" colspan="2">pixelwise-batch-avg-clip-score-cdf-adaptive</th>
#       <th id="T_1af3c_level1_col3" class="col_heading level1 col3" >pixelwise-batch-avg</th>
#       <th id="T_1af3c_level1_col4" class="col_heading level1 col4" colspan="2">pixelwise-batch-avg-clip-score-cdf-adaptive</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >loss_empirical_cdf_clip_threshold</th>
#       <th id="T_1af3c_level2_col0" class="col_heading level2 col0" >nan</th>
#       <th id="T_1af3c_level2_col1" class="col_heading level2 col1" >0.05</th>
#       <th id="T_1af3c_level2_col2" class="col_heading level2 col2" >0.15</th>
#       <th id="T_1af3c_level2_col3" class="col_heading level2 col3" >nan</th>
#       <th id="T_1af3c_level2_col4" class="col_heading level2 col4" >0.05</th>
#       <th id="T_1af3c_level2_col5" class="col_heading level2 col5" >0.15</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mvtec_class_type</th>
#       <th class="index_name level1" >normal_class_fullqualified</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1af3c_level0_row0" class="row_heading level0 row0" rowspan="10">object</th>
#       <th id="T_1af3c_level1_row0" class="row_heading level1 row0" >mvtec_00_bottle</th>
#       <td id="T_1af3c_row0_col0" class="data row0 col0" >67.3 (5.4) [65.5]</td>
#       <td id="T_1af3c_row0_col1" class="data row0 col1" >67.3 (7.9) [62.4]</td>
#       <td id="T_1af3c_row0_col2" class="data row0 col2" >57.3 (9.5) [53.0]</td>
#       <td id="T_1af3c_row0_col3" class="data row0 col3" >18.0 (0.5) [24.5]</td>
#       <td id="T_1af3c_row0_col4" class="data row0 col4" >18.8 (1.0) [27.8]</td>
#       <td id="T_1af3c_row0_col5" class="data row0 col5" >41.6 (6.7) [39.0]</td>
#     </tr>
#     <tr>
#       <th id="T_1af3c_level1_row1" class="row_heading level1 row1" >mvtec_01_cable</th>
#       <td id="T_1af3c_row1_col0" class="data row1 col0" >57.9 (4.0) [57.7]</td>
#       <td id="T_1af3c_row1_col1" class="data row1 col1" >57.8 (1.3) [56.3]</td>
#       <td id="T_1af3c_row1_col2" class="data row1 col2" >54.5 (2.6) [53.2]</td>
#       <td id="T_1af3c_row1_col3" class="data row1 col3" >53.1 (2.6) [50.7]</td>
#       <td id="T_1af3c_row1_col4" class="data row1 col4" >55.4 (1.5) [53.1]</td>
#       <td id="T_1af3c_row1_col5" class="data row1 col5" >47.0 (10.0) [45.2]</td>
#     </tr>
#     <tr>
#       <th id="T_1af3c_level1_row2" class="row_heading level1 row2" >mvtec_02_capsule</th>
#       <td id="T_1af3c_row2_col0" class="data row2 col0" >24.7 (11.5) [23.7]</td>
#       <td id="T_1af3c_row2_col1" class="data row2 col1" >16.2 (8.0) [16.2]</td>
#       <td id="T_1af3c_row2_col2" class="data row2 col2" >7.3 (5.2) [7.8]</td>
#       <td id="T_1af3c_row2_col3" class="data row2 col3" >9.3 (0.6) [12.7]</td>
#       <td id="T_1af3c_row2_col4" class="data row2 col4" >9.5 (0.7) [11.7]</td>
#       <td id="T_1af3c_row2_col5" class="data row2 col5" >11.5 (1.4) [12.2]</td>
#     </tr>
#     <tr>
#       <th id="T_1af3c_level1_row3" class="row_heading level1 row3" >mvtec_05_hazelnut</th>
#       <td id="T_1af3c_row3_col0" class="data row3 col0" >50.7 (7.7) [51.3]</td>
#       <td id="T_1af3c_row3_col1" class="data row3 col1" >43.1 (5.2) [45.3]</td>
#       <td id="T_1af3c_row3_col2" class="data row3 col2" >30.2 (1.6) [31.1]</td>
#       <td id="T_1af3c_row3_col3" class="data row3 col3" >13.9 (2.1) [19.0]</td>
#       <td id="T_1af3c_row3_col4" class="data row3 col4" >14.6 (1.7) [19.7]</td>
#       <td id="T_1af3c_row3_col5" class="data row3 col5" >22.2 (9.2) [28.1]</td>
#     </tr>
#     <tr>
#       <th id="T_1af3c_level1_row4" class="row_heading level1 row4" >mvtec_07_metal_nut</th>
#       <td id="T_1af3c_row4_col0" class="data row4 col0" >86.1 (2.0) [87.5]</td>
#       <td id="T_1af3c_row4_col1" class="data row4 col1" >89.4 (2.5) [88.3]</td>
#       <td id="T_1af3c_row4_col2" class="data row4 col2" >85.4 (1.4) [83.8]</td>
#       <td id="T_1af3c_row4_col3" class="data row4 col3" >10.4 (0.3) [11.3]</td>
#       <td id="T_1af3c_row4_col4" class="data row4 col4" >10.6 (0.5) [11.7]</td>
#       <td id="T_1af3c_row4_col5" class="data row4 col5" >17.9 (3.0) [16.1]</td>
#     </tr>
#     <tr>
#       <th id="T_1af3c_level1_row5" class="row_heading level1 row5" >mvtec_08_pill</th>
#       <td id="T_1af3c_row5_col0" class="data row5 col0" >64.8 (8.7) [66.8]</td>
#       <td id="T_1af3c_row5_col1" class="data row5 col1" >55.9 (17.1) [54.8]</td>
#       <td id="T_1af3c_row5_col2" class="data row5 col2" >59.5 (12.3) [56.0]</td>
#       <td id="T_1af3c_row5_col3" class="data row5 col3" >2.4 (0.0) [2.4]</td>
#       <td id="T_1af3c_row5_col4" class="data row5 col4" >2.5 (0.2) [2.5]</td>
#       <td id="T_1af3c_row5_col5" class="data row5 col5" >2.5 (0.2) [2.8]</td>
#     </tr>
#     <tr>
#       <th id="T_1af3c_level1_row6" class="row_heading level1 row6" >mvtec_09_screw</th>
#       <td id="T_1af3c_row6_c
