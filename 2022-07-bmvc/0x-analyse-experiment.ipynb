# %%
# make a cell print all the outputs instead of just the last one
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from pathlib import Path

data_dir = Path("./data")
data_fpath = data_dir / "2022-07-bmvc-report-01-data00-scheduler-params.csv"

import pandas as pd
df = pd.read_csv(data_fpath) 

def check_df(df):
    print(df.shape)
    print(df.dtypes)
    return df.head(5)

check_df(df)
# Out:
# (610, 12)
# Name                                  object
# supervise_mode                        object
# normal_class_fullqualified            object
# loss                                  object
# loss_empirical_cdf_clip_threshold    float64
# validate/roc-auc-histavg             float64
# validate/avg-precision-histavg       float64
# scheduler_parameters                  object
# normal_class                           int64
# test/roc-auc                         float64
# test/avg-precision                   float64
# mvtec_class_type                      object
# dtype: object
#                      Name              supervise_mode  \
# 0  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
# 1  mvtec.mvtec.cls14.it01  synthetic-anomaly-confetti
# 2  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
# 3  mvtec.mvtec.cls14.it01  synthetic-anomaly-confetti
# 4  mvtec.mvtec.cls14.it00  synthetic-anomaly-confetti
#
#   normal_class_fullqualified                 loss  \
# 0            mvtec_14_zipper  pixelwise-batch-avg
# 1            mvtec_14_zipper  pixelwise-batch-avg
# 2            mvtec_14_zipper  pixelwise-batch-avg
# 3            mvtec_14_zipper  pixelwise-batch-avg
# 4            mvtec_14_zipper  pixelwise-batch-avg
#
#    loss_empirical_cdf_clip_threshold  validate/roc-auc-histavg  \
# 0                                NaN                  0.905855
# 1                                NaN                  0.893223
# 2                                NaN                  0.923746
# 3                                NaN                  0.925055
# 4                                NaN                  0.875511
#
#    validate/avg-precision-histavg scheduler_parameters  normal_class  \
# 0                        0.341559             [0.9985]            14
# 1                        0.335284             [0.9985]            14
# 2                        0.341422              [0.985]            14
# 3                        0.324699              [0.985]            14
# 4                        0.219284              [0.985]            14
#
#    test/roc-auc  test/avg-precision mvtec_class_type
# 0      0.888598            0.319318           object
# 1      0.863413            0.275698           object
# 2      0.927588            0.342631           object
# 3      0.934807            0.332482           object
# 4      0.913435            0.248363           object

# %%
data_df = pd.read_csv(data_fpath) 
df = data_df
df["scheduler_parameters"] = df["scheduler_parameters"].apply(lambda x: float(x.lstrip("[").rstrip("]")))
df["scheduler_parameters"] = df["scheduler_parameters"].apply(lambda x: {0.985000: "higher decay", 0.998500: "equiv. decay"}[x])
df.drop(columns=["Name"], inplace=True)
check_df(df)
# Out:
# (610, 11)
# supervise_mode                        object
# normal_class_fullqualified            object
# loss                                  object
# loss_empirical_cdf_clip_threshold    float64
# validate/roc-auc-histavg             float64
# validate/avg-precision-histavg       float64
# scheduler_parameters                  object
# normal_class                           int64
# test/roc-auc                         float64
# test/avg-precision                   float64
# mvtec_class_type                      object
# dtype: object
#                supervise_mode normal_class_fullqualified                 loss  \
# 0  synthetic-anomaly-confetti            mvtec_14_zipper  pixelwise-batch-avg
# 1  synthetic-anomaly-confetti            mvtec_14_zipper  pixelwise-batch-avg
# 2  synthetic-anomaly-confetti            mvtec_14_zipper  pixelwise-batch-avg
# 3  synthetic-anomaly-confetti            mvtec_14_zipper  pixelwise-batch-avg
# 4  synthetic-anomaly-confetti            mvtec_14_zipper  pixelwise-batch-avg
#
#    loss_empirical_cdf_clip_threshold  validate/roc-auc-histavg  \
# 0                                NaN                      0.91
# 1                                NaN                      0.89
# 2                                NaN                      0.92
# 3                                NaN                      0.93
# 4                                NaN                      0.88
#
#    validate/avg-precision-histavg scheduler_parameters  normal_class  \
# 0                            0.34         equiv. decay            14
# 1                            0.34         equiv. decay            14
# 2                            0.34         higher decay            14
# 3                            0.32         higher decay            14
# 4                            0.22         higher decay            14
#
#    test/roc-auc  test/avg-precision mvtec_class_type
# 0          0.89                0.32           object
# 1          0.86                0.28           object
# 2          0.93                0.34           object
# 3          0.93                0.33           object
# 4          0.91                0.25           object

# %%
data_df = df

# %%
from pandas import DataFrame
import pandas as pd
import numpy as np
from functools import partial

def get_color_mask_compare_by_line_every_n_cols(pt, n):
    
    if n > 2:
        raise NotImplemented("n > 2 is not implemented ===> deal with color scale!")
    
    assert pt.shape[1] % n == 0, f"pt.shape[1] % n != 0: {pt.shape[1] % n}"

    def get_ordering_signal(arr: np.ndarray) -> np.ndarray:
        """at each line, the values are assigned a value from 0 to 1 respecting the ordering, such that 0 is the min and 1 is the max"""
        # it's ok to round up to 3 decimals because i will probably never have more than 1001 values
        # and it makes the table easier to read/debug
        assert arr.shape[1] < 1001, f"arr.shape[1] < 1001: {arr.shape[1]}"
        return np.round(np.argsort(arr) / (n - 1), decimals=3)

    return np.concatenate(
        [   
            get_ordering_signal(pt.iloc[:, i * n:(i + 1) *n].values)
            for i in range(pt.shape[1] // n)
        ],
        axis=1,
    )
    
COLOR_0 = 'background-color: #DC143C'
COLOR_1 = 'background-color: #228B22'
    
def color_from_mask(color_mask: np.ndarray):
    
    def color(_):
        colormap = np.empty_like(color_mask, dtype=object)
        colormap[color_mask == 0] = COLOR_0
        colormap[color_mask == 1] = COLOR_1
        return colormap
    
    return color

# %%
from pandas import DataFrame
import pandas as pd
import numpy as np
from functools import partial

df = data_df.copy()

row_cols = ["mvtec_class_type", "normal_class_fullqualified"]
column_cols = ["supervise_mode", "loss", "scheduler_parameters"]

metrics = {
    "test/avg-precision": ["mean", "std"],
    "validate/avg-precision-histavg": ["mean",],
    # "test/roc-auc": ["mean", "std"],
    # "validate/roc-auc"": ["mean",],
}
metric_cols = [(k, v) for k, list_vals in metrics.items() for v in list_vals]

pt_all_metrics = pd.pivot_table(df, index=row_cols, columns=column_cols, aggfunc=metrics)

# when it's a percentage
pt_all_metrics = 100 * pt_all_metrics

pt_test_avg = pt_all_metrics[("test/avg-precision", "mean")]
pt_test_avg.loc[("", "object mean"), :] = pt_test_avg.loc["object"].mean(axis=0)
pt_test_avg.loc[("", "texture mean"), :] = pt_test_avg.loc["texture"].mean(axis=0)
pt_test_avg.loc[("", "all mean"), :] = pt_test_avg.mean(axis=0)

pt_test_std = pt_all_metrics[("test/avg-precision", "std")]
pt_test_std.loc[("", "object mean"), :] = pt_test_std.loc["object"].mean(axis=0)
pt_test_std.loc[("", "texture mean"), :] = pt_test_std.loc["texture"].mean(axis=0)
pt_test_std.loc[("", "all mean"), :] = pt_test_std.mean(axis=0)

pt_validate_histmean_avg = pt_all_metrics[("validate/avg-precision-histavg", "mean")]
pt_validate_histmean_avg.loc[("", "object mean"), :] = pt_validate_histmean_avg.loc["object"].mean(axis=0)
pt_validate_histmean_avg.loc[("", "texture mean"), :] = pt_validate_histmean_avg.loc["texture"].mean(axis=0)
pt_validate_histmean_avg.loc[("", "all mean"), :] = pt_validate_histmean_avg.mean(axis=0)

pt_composed = pt_test_avg.applymap("{:.1f}".format) + " " + pt_test_std.applymap("({:.1f})".format) + " " + pt_validate_histmean_avg.applymap("[{:.1f}]".format)
# Out:
# /tmp/ipykernel_11129/3268568984.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_test_avg.loc[("", "object mean"), :] = pt_test_avg.loc["object"].mean(axis=0)
# /tmp/ipykernel_11129/3268568984.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_test_std.loc[("", "object mean"), :] = pt_test_std.loc["object"].mean(axis=0)
# /tmp/ipykernel_11129/3268568984.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pt_validate_histmean_avg.loc[("", "object mean"), :] = pt_validate_histmean_avg.loc["object"].mean(axis=0)

# %% [markdown]
# # compare all

# %%
pt = pt_composed.copy()
pt_color_from = pt_test_avg.copy()
color_mask = get_color_mask_compare_by_line_every_n_cols(pt_color_from, n=2)
pt.style.apply(color_from_mask(color_mask), axis=None)
# Out:
# <style type="text/css">
# #T_18136_row0_col0, #T_18136_row0_col3, #T_18136_row0_col5, #T_18136_row0_col7, #T_18136_row1_col0, #T_18136_row1_col2, #T_18136_row1_col4, #T_18136_row1_col6, #T_18136_row2_col0, #T_18136_row2_col2, #T_18136_row2_col4, #T_18136_row2_col7, #T_18136_row3_col0, #T_18136_row3_col2, #T_18136_row3_col5, #T_18136_row3_col7, #T_18136_row4_col1, #T_18136_row4_col3, #T_18136_row4_col5, #T_18136_row4_col7, #T_18136_row5_col0, #T_18136_row5_col3, #T_18136_row5_col4, #T_18136_row5_col6, #T_18136_row6_col0, #T_18136_row6_col2, #T_18136_row6_col5, #T_18136_row6_col7, #T_18136_row7_col0, #T_18136_row7_col3, #T_18136_row7_col5, #T_18136_row7_col7, #T_18136_row8_col0, #T_18136_row8_col2, #T_18136_row8_col4, #T_18136_row8_col7, #T_18136_row9_col0, #T_18136_row9_col3, #T_18136_row9_col4, #T_18136_row9_col7, #T_18136_row10_col0, #T_18136_row10_col3, #T_18136_row10_col5, #T_18136_row10_col7, #T_18136_row11_col0, #T_18136_row11_col3, #T_18136_row11_col4, #T_18136_row11_col6, #T_18136_row12_col0, #T_18136_row12_col2, #T_18136_row12_col5, #T_18136_row12_col7, #T_18136_row13_col0, #T_18136_row13_col2, #T_18136_row13_col4, #T_18136_row13_col6, #T_18136_row14_col0, #T_18136_row14_col3, #T_18136_row14_col4, #T_18136_row14_col7, #T_18136_row15_col0, #T_18136_row15_col2, #T_18136_row15_col4, #T_18136_row15_col7, #T_18136_row16_col0, #T_18136_row16_col3, #T_18136_row16_col4, #T_18136_row16_col7, #T_18136_row17_col0, #T_18136_row17_col3, #T_18136_row17_col4, #T_18136_row17_col7 {
#   background-color: #228B22;
# }
# #T_18136_row0_col1, #T_18136_row0_col2, #T_18136_row0_col4, #T_18136_row0_col6, #T_18136_row1_col1, #T_18136_row1_col3, #T_18136_row1_col5, #T_18136_row1_col7, #T_18136_row2_col1, #T_18136_row2_col3, #T_18136_row2_col5, #T_18136_row2_col6, #T_18136_row3_col1, #T_18136_row3_col3, #T_18136_row3_col4, #T_18136_row3_col6, #T_18136_row4_col0, #T_18136_row4_col2, #T_18136_row4_col4, #T_18136_row4_col6, #T_18136_row5_col1, #T_18136_row5_col2, #T_18136_row5_col5, #T_18136_row5_col7, #T_18136_row6_col1, #T_18136_row6_col3, #T_18136_row6_col4, #T_18136_row6_col6, #T_18136_row7_col1, #T_18136_row7_col2, #T_18136_row7_col4, #T_18136_row7_col6, #T_18136_row8_col1, #T_18136_row8_col3, #T_18136_row8_col5, #T_18136_row8_col6, #T_18136_row9_col1, #T_18136_row9_col2, #T_18136_row9_col5, #T_18136_row9_col6, #T_18136_row10_col1, #T_18136_row10_col2, #T_18136_row10_col4, #T_18136_row10_col6, #T_18136_row11_col1, #T_18136_row11_col2, #T_18136_row11_col5, #T_18136_row11_col7, #T_18136_row12_col1, #T_18136_row12_col3, #T_18136_row12_col4, #T_18136_row12_col6, #T_18136_row13_col1, #T_18136_row13_col3, #T_18136_row13_col5, #T_18136_row13_col7, #T_18136_row14_col1, #T_18136_row14_col2, #T_18136_row14_col5, #T_18136_row14_col6, #T_18136_row15_col1, #T_18136_row15_col3, #T_18136_row15_col5, #T_18136_row15_col6, #T_18136_row16_col1, #T_18136_row16_col2, #T_18136_row16_col5, #T_18136_row16_col6, #T_18136_row17_col1, #T_18136_row17_col2, #T_18136_row17_col5, #T_18136_row17_col6 {
#   background-color: #DC143C;
# }
# </style>
# <table id="T_18136">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >supervise_mode</th>
#       <th id="T_18136_level0_col0" class="col_heading level0 col0" colspan="4">real-anomaly</th>
#       <th id="T_18136_level0_col4" class="col_heading level0 col4" colspan="4">synthetic-anomaly-confetti</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >loss</th>
#       <th id="T_18136_level1_col0" class="col_heading level1 col0" colspan="2">old-fcdd</th>
#       <th id="T_18136_level1_col2" class="col_heading level1 col2" colspan="2">pixelwise-batch-avg</th>
#       <th id="T_18136_level1_col4" class="col_heading level1 col4" colspan="2">old-fcdd</th>
#       <th id="T_18136_level1_col6" class="col_heading level1 col6" colspan="2">pixelwise-batch-avg</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >scheduler_parameters</th>
#       <th id="T_18136_level2_col0" class="col_heading level2 col0" >equiv. decay</th>
#       <th id="T_18136_level2_col1" class="col_heading level2 col1" >higher decay</th>
#       <th id="T_18136_level2_col2" class="col_heading level2 col2" >equiv. decay</th>
#       <th id="T_18136_level2_col3" class="col_heading level2 col3" >higher decay</th>
#       <th id="T_18136_level2_col4" class="col_heading level2 col4" >equiv. decay</th>
#       <th id="T_18136_level2_col5" class="col_heading level2 col5" >higher decay</th>
#       <th id="T_18136_level2_col6" class="col_heading level2 col6" >equiv. decay</th>
#       <th id="T_18136_level2_col7" class="col_heading level2 col7" >higher decay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mvtec_class_type</th>
#       <th class="index_name level1" >normal_class_fullqualified</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18136_level0_row0" class="row_heading level0 row0" rowspan="10">object</th>
#       <th id="T_18136_level1_row0" class="row_heading level1 row0" >mvtec_00_bottle</th>
#       <td id="T_18136_row0_col0" class="data row0 col0" >65.3 (8.0) [56.7]</td>
#       <td id="T_18136_row0_col1" class="data row0 col1" >50.1 (13.3) [45.8]</td>
#       <td id="T_18136_row0_col2" class="data row0 col2" >67.3 (5.4) [65.5]</td>
#       <td id="T_18136_row0_col3" class="data row0 col3" >68.1 (6.1) [66.3]</td>
#       <td id="T_18136_row0_col4" class="data row0 col4" >25.3 (2.5) [30.1]</td>
#       <td id="T_18136_row0_col5" class="data row0 col5" >36.0 (6.3) [32.6]</td>
#       <td id="T_18136_row0_col6" class="data row0 col6" >18.0 (0.5) [24.5]</td>
#       <td id="T_18136_row0_col7" class="data row0 col7" >37.6 (3.4) [39.7]</td>
#     </tr>
#     <tr>
#       <th id="T_18136_level1_row1" class="row_heading level1 row1" >mvtec_01_cable</th>
#       <td id="T_18136_row1_col0" class="data row1 col0" >57.4 (2.4) [51.6]</td>
#       <td id="T_18136_row1_col1" class="data row1 col1" >44.4 (3.2) [43.6]</td>
#       <td id="T_18136_row1_col2" class="data row1 col2" >57.9 (4.0) [57.7]</td>
#       <td id="T_18136_row1_col3" class="data row1 col3" >57.3 (1.9) [56.1]</td>
#       <td id="T_18136_row1_col4" class="data row1 col4" >48.6 (2.2) [46.1]</td>
#       <td id="T_18136_row1_col5" class="data row1 col5" >43.6 (0.8) [43.4]</td>
#       <td id="T_18136_row1_col6" class="data row1 col6" >53.1 (2.6) [50.7]</td>
#       <td id="T_18136_row1_col7" class="data row1 col7" >46.0 (7.7) [46.0]</td>
#     </tr>
#     <tr>
#       <th id="T_18136_level1_row2" class="row_heading level1 row2" >mvtec_02_capsule</th>
#       <td id="T_18136_row2_col0" class="data row2 col0" >7.7 (5.5) [7.5]</td>
#       <td id="T_18136_row2_col1" class="data row2 col1" >6.4 (2.2) [7.0]</td>
#       <td id="T_18136_row2_col2" class="data row2 col2" >24.7 (11.5) [23.7]</td>
#       <td id="T_18136_row2_col3" class="data row2 col3" >13.5 (9.4) [14.0]</td>
#       <td id="T_18136_row2_col4" class="data row2 col4" >12.7 (2.1) [11.7]</td>
#       <td id="T_18136_row2_col5" class="data row2 col5" >7.9 (1.6) [8.5]</td>
#       <td id="T_18136_row2_col6" class="data row2 col6" >9.3 (0.6) [12.7]</td>
#       <td id="T_18136_row2_col7" class="data row2 col7" >12.4 (1.8) [14.8]</td>
#     </tr>
#     <tr>
#       <th id="T_18136_level1_row3" class="row_heading level1 row3" >mvtec_05_hazelnut</th>
#       <td id="T_18136_row3_col0" class="data row3 col0" >43.5 (10.9) [41.6]</td>
#       <td id="T_18136_row3_col1" class="data row3 col1" >38.4 (6.5) [38.5]</td>
#       <td id="T_18136_row3_col2" class="data row3 col2" >50.7 (7.7) [51.3]</td>
#       <td id="T_18136_row3_col3" class="data row3 col3" >46.5 (10.1) [48.4]</td>
#       <td id="T_18136_row3_col4" class="data r

# %% [markdown]
# # fixed loss

# %% [markdown]
# ## old-fcdd

# %%
pt = pt_composed.loc[:, (slice(None), "old-fcdd")].copy()
pt_color_from = pt_test_avg.loc[:, (slice(None), "old-fcdd")].copy()
color_mask = get_color_mask_compare_by_line_every_n_cols(pt_color_from, n=2)
pt.style.apply(color_from_mask(color_mask), axis=None)
# Out:
# <style type="text/css">
# #T_23113_row0_col0, #T_23113_row0_col3, #T_23113_row1_col0, #T_23113_row1_col2, #T_23113_row2_col0, #T_23113_row2_col2, #T_23113_row3_col0, #T_23113_row3_col3, #T_23113_row4_col1, #T_23113_row4_col3, #T_23113_row5_col0, #T_23113_row5_col2, #T_23113_row6_col0, #T_23113_row6_col3, #T_23113_row7_col0, #T_23113_row7_col3, #T_23113_row8_col0, #T_23113_row8_col2, #T_23113_row9_col0, #T_23113_row9_col2, #T_23113_row10_col0, #T_23113_row10_col3, #T_23113_row11_col0, #T_23113_row11_col2, #T_23113_row12_col0, #T_23113_row12_col3, #T_23113_row13_col0, #T_23113_row13_col2, #T_23113_row14_col0, #T_23113_row14_col2, #T_23113_row15_col0, #T_23113_row15_col2, #T_23113_row16_col0, #T_23113_row16_col2, #T_23113_row17_col0, #T_23113_row17_col2 {
#   background-color: #228B22;
# }
# #T_23113_row0_col1, #T_23113_row0_col2, #T_23113_row1_col1, #T_23113_row1_col3, #T_23113_row2_col1, #T_23113_row2_col3, #T_23113_row3_col1, #T_23113_row3_col2, #T_23113_row4_col0, #T_23113_row4_col2, #T_23113_row5_col1, #T_23113_row5_col3, #T_23113_row6_col1, #T_23113_row6_col2, #T_23113_row7_col1, #T_23113_row7_col2, #T_23113_row8_col1, #T_23113_row8_col3, #T_23113_row9_col1, #T_23113_row9_col3, #T_23113_row10_col1, #T_23113_row10_col2, #T_23113_row11_col1, #T_23113_row11_col3, #T_23113_row12_col1, #T_23113_row12_col2, #T_23113_row13_col1, #T_23113_row13_col3, #T_23113_row14_col1, #T_23113_row14_col3, #T_23113_row15_col1, #T_23113_row15_col3, #T_23113_row16_col1, #T_23113_row16_col3, #T_23113_row17_col1, #T_23113_row17_col3 {
#   background-color: #DC143C;
# }
# </style>
# <table id="T_23113">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >supervise_mode</th>
#       <th id="T_23113_level0_col0" class="col_heading level0 col0" colspan="2">real-anomaly</th>
#       <th id="T_23113_level0_col2" class="col_heading level0 col2" colspan="2">synthetic-anomaly-confetti</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >loss</th>
#       <th id="T_23113_level1_col0" class="col_heading level1 col0" colspan="2">old-fcdd</th>
#       <th id="T_23113_level1_col2" class="col_heading level1 col2" colspan="2">old-fcdd</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >scheduler_parameters</th>
#       <th id="T_23113_level2_col0" class="col_heading level2 col0" >equiv. decay</th>
#       <th id="T_23113_level2_col1" class="col_heading level2 col1" >higher decay</th>
#       <th id="T_23113_level2_col2" class="col_heading level2 col2" >equiv. decay</th>
#       <th id="T_23113_level2_col3" class="col_heading level2 col3" >higher decay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mvtec_class_type</th>
#       <th class="index_name level1" >normal_class_fullqualified</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23113_level0_row0" class="row_heading level0 row0" rowspan="10">object</th>
#       <th id="T_23113_level1_row0" class="row_heading level1 row0" >mvtec_00_bottle</th>
#       <td id="T_23113_row0_col0" class="data row0 col0" >65.3 (8.0) [56.7]</td>
#       <td id="T_23113_row0_col1" class="data row0 col1" >50.1 (13.3) [45.8]</td>
#       <td id="T_23113_row0_col2" class="data row0 col2" >25.3 (2.5) [30.1]</td>
#       <td id="T_23113_row0_col3" class="data row0 col3" >36.0 (6.3) [32.6]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row1" class="row_heading level1 row1" >mvtec_01_cable</th>
#       <td id="T_23113_row1_col0" class="data row1 col0" >57.4 (2.4) [51.6]</td>
#       <td id="T_23113_row1_col1" class="data row1 col1" >44.4 (3.2) [43.6]</td>
#       <td id="T_23113_row1_col2" class="data row1 col2" >48.6 (2.2) [46.1]</td>
#       <td id="T_23113_row1_col3" class="data row1 col3" >43.6 (0.8) [43.4]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row2" class="row_heading level1 row2" >mvtec_02_capsule</th>
#       <td id="T_23113_row2_col0" class="data row2 col0" >7.7 (5.5) [7.5]</td>
#       <td id="T_23113_row2_col1" class="data row2 col1" >6.4 (2.2) [7.0]</td>
#       <td id="T_23113_row2_col2" class="data row2 col2" >12.7 (2.1) [11.7]</td>
#       <td id="T_23113_row2_col3" class="data row2 col3" >7.9 (1.6) [8.5]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row3" class="row_heading level1 row3" >mvtec_05_hazelnut</th>
#       <td id="T_23113_row3_col0" class="data row3 col0" >43.5 (10.9) [41.6]</td>
#       <td id="T_23113_row3_col1" class="data row3 col1" >38.4 (6.5) [38.5]</td>
#       <td id="T_23113_row3_col2" class="data row3 col2" >13.3 (1.8) [20.8]</td>
#       <td id="T_23113_row3_col3" class="data row3 col3" >29.7 (3.0) [30.4]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row4" class="row_heading level1 row4" >mvtec_07_metal_nut</th>
#       <td id="T_23113_row4_col0" class="data row4 col0" >86.1 (3.2) [86.7]</td>
#       <td id="T_23113_row4_col1" class="data row4 col1" >88.9 (0.4) [85.6]</td>
#       <td id="T_23113_row4_col2" class="data row4 col2" >11.5 (2.2) [12.2]</td>
#       <td id="T_23113_row4_col3" class="data row4 col3" >16.5 (2.7) [16.5]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row5" class="row_heading level1 row5" >mvtec_08_pill</th>
#       <td id="T_23113_row5_col0" class="data row5 col0" >66.6 (8.4) [64.1]</td>
#       <td id="T_23113_row5_col1" class="data row5 col1" >60.8 (12.9) [59.6]</td>
#       <td id="T_23113_row5_col2" class="data row5 col2" >2.2 (0.0) [3.6]</td>
#       <td id="T_23113_row5_col3" class="data row5 col3" >2.1 (0.1) [2.4]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row6" class="row_heading level1 row6" >mvtec_09_screw</th>
#       <td id="T_23113_row6_col0" class="data row6 col0" >3.4 (2.3) [3.8]</td>
#       <td id="T_23113_row6_col1" class="data row6 col1" >0.9 (0.2) [1.6]</td>
#       <td id="T_23113_row6_col2" class="data row6 col2" >0.7 (0.1) [1.3]</td>
#       <td id="T_23113_row6_col3" class="data row6 col3" >0.9 (0.2) [1.7]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row7" class="row_heading level1 row7" >mvtec_11_toothbrush</th>
#       <td id="T_23113_row7_col0" class="data row7 col0" >17.1 (15.9) [16.7]</td>
#       <td id="T_23113_row7_col1" class="data row7 col1" >15.9 (18.3) [15.4]</td>
#       <td id="T_23113_row7_col2" class="data row7 col2" >1.5 (0.5) [2.9]</td>
#       <td id="T_23113_row7_col3" class="data row7 col3" >6.3 (6.1) [7.1]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row8" class="row_heading level1 row8" >mvtec_12_transistor</th>
#       <td id="T_23113_row8_col0" class="data row8 col0" >50.8 (4.4) [39.8]</td>
#       <td id="T_23113_row8_col1" class="data row8 col1" >31.8 (3.6) [30.8]</td>
#       <td id="T_23113_row8_col2" class="data row8 col2" >39.2 (1.7) [35.5]</td>
#       <td id="T_23113_row8_col3" class="data row8 col3" >24.4 (6.2) [22.5]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row9" class="row_heading level1 row9" >mvtec_14_zipper</th>
#       <td id="T_23113_row9_col0" class="data row9 col0" >64.9 (3.1) [47.2]</td>
#       <td id="T_23113_row9_col1" class="data row9 col1" >14.6 (7.2) [14.1]</td>
#       <td id="T_23113_row9_col2" class="data row9 col2" >30.5 (3.1) [28.6]</td>
#       <td id="T_23113_row9_col3" class="data row9 col3" >7.4 (5.3) [7.4]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level0_row10" class="row_heading level0 row10" rowspan="5">texture</th>
#       <th id="T_23113_level1_row10" class="row_heading level1 row10" >mvtec_03_carpet</th>
#       <td id="T_23113_row10_col0" class="data row10 col0" >72.9 (1.5) [71.1]</td>
#       <td id="T_23113_row10_col1" class="data row10 col1" >69.0 (3.4) [66.5]</td>
#       <td id="T_23113_row10_col2" class="data row10 col2" >37.6 (0.7) [41.5]</td>
#       <td id="T_23113_row10_col3" class="data row10 col3" >38.1 (5.9) [37.1]</td>
#     </tr>
#     <tr>
#       <th id="T_23113_level1_row11" class="row_heading level1 row11" >mvtec_04_grid</th

# %% [markdown]
# ## pixelwise-batch-avg

# %%
pt = pt_composed.loc[:, (slice(None), "pixelwise-batch-avg")].copy()
pt_color_from = pt_test_avg.loc[:, (slice(None), "pixelwise-batch-avg")].copy()
color_mask = get_color_mask_compare_by_line_every_n_cols(pt_color_from, n=2)
pt.style.apply(color_from_mask(color_mask), axis=None)
# Out:
# <style type="text/css">
# #T_fe2db_row0_col0, #T_fe2db_row0_col2, #T_fe2db_row1_col1, #T_fe2db_row1_col3, #T_fe2db_row2_col1, #T_fe2db_row2_col2, #T_fe2db_row3_col1, #T_fe2db_row3_col2, #T_fe2db_row4_col0, #T_fe2db_row4_col2, #T_fe2db_row5_col0, #T_fe2db_row5_col3, #T_fe2db_row6_col1, #T_fe2db_row6_col2, #T_fe2db_row7_col0, #T_fe2db_row7_col2, #T_fe2db_row8_col1, #T_fe2db_row8_col2, #T_fe2db_row9_col0, #T_fe2db_row9_col2, #T_fe2db_row10_col0, #T_fe2db_row10_col2, #T_fe2db_row11_col0, #T_fe2db_row11_col3, #T_fe2db_row12_col1, #T_fe2db_row12_col2, #T_fe2db_row13_col1, #T_fe2db_row13_col3, #T_fe2db_row14_col0, #T_fe2db_row14_col2, #T_fe2db_row15_col1, #T_fe2db_row15_col2, #T_fe2db_row16_col0, #T_fe2db_row16_col2, #T_fe2db_row17_col0, #T_fe2db_row17_col2 {
#   background-color: #DC143C;
# }
# #T_fe2db_row0_col1, #T_fe2db_row0_col3, #T_fe2db_row1_col0, #T_fe2db_row1_col2, #T_fe2db_row2_col0, #T_fe2db_row2_col3, #T_fe2db_row3_col0, #T_fe2db_row3_col3, #T_fe2db_row4_col1, #T_fe2db_row4_col3, #T_fe2db_row5_col1, #T_fe2db_row5_col2, #T_fe2db_row6_col0, #T_fe2db_row6_col3, #T_fe2db_row7_col1, #T_fe2db_row7_col3, #T_fe2db_row8_col0, #T_fe2db_row8_col3, #T_fe2db_row9_col1, #T_fe2db_row9_col3, #T_fe2db_row10_col1, #T_fe2db_row10_col3, #T_fe2db_row11_col1, #T_fe2db_row11_col2, #T_fe2db_row12_col0, #T_fe2db_row12_col3, #T_fe2db_row13_col0, #T_fe2db_row13_col2, #T_fe2db_row14_col1, #T_fe2db_row14_col3, #T_fe2db_row15_col0, #T_fe2db_row15_col3, #T_fe2db_row16_col1, #T_fe2db_row16_col3, #T_fe2db_row17_col1, #T_fe2db_row17_col3 {
#   background-color: #228B22;
# }
# </style>
# <table id="T_fe2db">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >supervise_mode</th>
#       <th id="T_fe2db_level0_col0" class="col_heading level0 col0" colspan="2">real-anomaly</th>
#       <th id="T_fe2db_level0_col2" class="col_heading level0 col2" colspan="2">synthetic-anomaly-confetti</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >loss</th>
#       <th id="T_fe2db_level1_col0" class="col_heading level1 col0" colspan="2">pixelwise-batch-avg</th>
#       <th id="T_fe2db_level1_col2" class="col_heading level1 col2" colspan="2">pixelwise-batch-avg</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >scheduler_parameters</th>
#       <th id="T_fe2db_level2_col0" class="col_heading level2 col0" >equiv. decay</th>
#       <th id="T_fe2db_level2_col1" class="col_heading level2 col1" >higher decay</th>
#       <th id="T_fe2db_level2_col2" class="col_heading level2 col2" >equiv. decay</th>
#       <th id="T_fe2db_level2_col3" class="col_heading level2 col3" >higher decay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mvtec_class_type</th>
#       <th class="index_name level1" >normal_class_fullqualified</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe2db_level0_row0" class="row_heading level0 row0" rowspan="10">object</th>
#       <th id="T_fe2db_level1_row0" class="row_heading level1 row0" >mvtec_00_bottle</th>
#       <td id="T_fe2db_row0_col0" class="data row0 col0" >67.3 (5.4) [65.5]</td>
#       <td id="T_fe2db_row0_col1" class="data row0 col1" >68.1 (6.1) [66.3]</td>
#       <td id="T_fe2db_row0_col2" class="data row0 col2" >18.0 (0.5) [24.5]</td>
#       <td id="T_fe2db_row0_col3" class="data row0 col3" >37.6 (3.4) [39.7]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row1" class="row_heading level1 row1" >mvtec_01_cable</th>
#       <td id="T_fe2db_row1_col0" class="data row1 col0" >57.9 (4.0) [57.7]</td>
#       <td id="T_fe2db_row1_col1" class="data row1 col1" >57.3 (1.9) [56.1]</td>
#       <td id="T_fe2db_row1_col2" class="data row1 col2" >53.1 (2.6) [50.7]</td>
#       <td id="T_fe2db_row1_col3" class="data row1 col3" >46.0 (7.7) [46.0]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row2" class="row_heading level1 row2" >mvtec_02_capsule</th>
#       <td id="T_fe2db_row2_col0" class="data row2 col0" >24.7 (11.5) [23.7]</td>
#       <td id="T_fe2db_row2_col1" class="data row2 col1" >13.5 (9.4) [14.0]</td>
#       <td id="T_fe2db_row2_col2" class="data row2 col2" >9.3 (0.6) [12.7]</td>
#       <td id="T_fe2db_row2_col3" class="data row2 col3" >12.4 (1.8) [14.8]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row3" class="row_heading level1 row3" >mvtec_05_hazelnut</th>
#       <td id="T_fe2db_row3_col0" class="data row3 col0" >50.7 (7.7) [51.3]</td>
#       <td id="T_fe2db_row3_col1" class="data row3 col1" >46.5 (10.1) [48.4]</td>
#       <td id="T_fe2db_row3_col2" class="data row3 col2" >13.9 (2.1) [19.0]</td>
#       <td id="T_fe2db_row3_col3" class="data row3 col3" >21.8 (3.0) [25.2]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row4" class="row_heading level1 row4" >mvtec_07_metal_nut</th>
#       <td id="T_fe2db_row4_col0" class="data row4 col0" >86.1 (2.0) [87.5]</td>
#       <td id="T_fe2db_row4_col1" class="data row4 col1" >91.2 (1.2) [90.2]</td>
#       <td id="T_fe2db_row4_col2" class="data row4 col2" >10.4 (0.3) [11.3]</td>
#       <td id="T_fe2db_row4_col3" class="data row4 col3" >11.7 (1.9) [12.7]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row5" class="row_heading level1 row5" >mvtec_08_pill</th>
#       <td id="T_fe2db_row5_col0" class="data row5 col0" >64.8 (8.7) [66.8]</td>
#       <td id="T_fe2db_row5_col1" class="data row5 col1" >74.3 (5.0) [73.3]</td>
#       <td id="T_fe2db_row5_col2" class="data row5 col2" >2.4 (0.0) [2.4]</td>
#       <td id="T_fe2db_row5_col3" class="data row5 col3" >2.3 (0.2) [2.3]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row6" class="row_heading level1 row6" >mvtec_09_screw</th>
#       <td id="T_fe2db_row6_col0" class="data row6 col0" >6.4 (1.3) [9.6]</td>
#       <td id="T_fe2db_row6_col1" class="data row6 col1" >5.1 (2.3) [8.2]</td>
#       <td id="T_fe2db_row6_col2" class="data row6 col2" >0.5 (0.2) [1.6]</td>
#       <td id="T_fe2db_row6_col3" class="data row6 col3" >1.0 (0.2) [2.1]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row7" class="row_heading level1 row7" >mvtec_11_toothbrush</th>
#       <td id="T_fe2db_row7_col0" class="data row7 col0" >15.6 (7.5) [16.6]</td>
#       <td id="T_fe2db_row7_col1" class="data row7 col1" >26.0 (15.2) [27.2]</td>
#       <td id="T_fe2db_row7_col2" class="data row7 col2" >2.6 (0.4) [3.3]</td>
#       <td id="T_fe2db_row7_col3" class="data row7 col3" >3.0 (1.0) [4.3]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row8" class="row_heading level1 row8" >mvtec_12_transistor</th>
#       <td id="T_fe2db_row8_col0" class="data row8 col0" >49.9 (4.1) [45.9]</td>
#       <td id="T_fe2db_row8_col1" class="data row8 col1" >35.4 (4.5) [33.7]</td>
#       <td id="T_fe2db_row8_col2" class="data row8 col2" >30.8 (0.7) [32.2]</td>
#       <td id="T_fe2db_row8_col3" class="data row8 col3" >35.2 (1.4) [35.4]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row9" class="row_heading level1 row9" >mvtec_14_zipper</th>
#       <td id="T_fe2db_row9_col0" class="data row9 col0" >63.2 (2.9) [60.1]</td>
#       <td id="T_fe2db_row9_col1" class="data row9 col1" >64.4 (1.6) [59.8]</td>
#       <td id="T_fe2db_row9_col2" class="data row9 col2" >27.4 (3.3) [31.2]</td>
#       <td id="T_fe2db_row9_col3" class="data row9 col3" >30.6 (3.8) [29.4]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level0_row10" class="row_heading level0 row10" rowspan="5">texture</th>
#       <th id="T_fe2db_level1_row10" class="row_heading level1 row10" >mvtec_03_carpet</th>
#       <td id="T_fe2db_row10_col0" class="data row10 col0" >71.6 (3.7) [71.2]</td>
#       <td id="T_fe2db_row10_col1" class="data row10 col1" >73.6 (1.9) [73.6]</td>
#       <td id="T_fe2db_row10_col2" class="data row10 col2" >41.6 (4.1) [44.3]</td>
#       <td id="T_fe2db_row10_col3" class="data row10 col3" >48.5 (8.1) [47.9]</td>
#     </tr>
#     <tr>
#       <th id="T_fe2db_level1_row11" class="row_heading level

# %% [markdown]
# # fixed decay

# %% [markdown]
# ## higher decay

# %%
pt = pt_composed.loc[:, (slice(None), slice(None), "higher decay")].copy()
pt_color_from = pt_test_avg.loc[:, (slice(None), slice(None), "higher decay")].copy()
color_mask = get_color_mask_compare_by_line_every_n_cols(pt_color_from, n=2)
pt.style.apply(color_from_mask(color_mask), axis=None)
# Out:
# <style type="text/css">
# #T_f48be_row0_col0, #T_f48be_row0_col2, #T_f48be_row1_col0, #T_f48be_row1_col2, #T_f48be_row2_col0, #T_f48be_row2_col2, #T_f48be_row3_col0, #T_f48be_row3_col3, #T_f48be_row4_col0, #T_f48be_row4_col3, #T_f48be_row5_col0, #T_f48be_row5_col2, #T_f48be_row6_col0, #T_f48be_row6_col2, #T_f48be_row7_col0, #T_f48be_row7_col3, #T_f48be_row8_col0, #T_f48be_row8_col2, #T_f48be_row9_col0, #T_f48be_row9_col2, #T_f48be_row10_col0, #T_f48be_row10_col2, #T_f48be_row11_col0, #T_f48be_row11_col2, #T_f48be_row12_col0, #T_f48be_row12_col3, #T_f48be_row13_col0, #T_f48be_row13_col2, #T_f48be_row14_col0, #T_f48be_row14_col2, #T_f48be_row15_col0, #T_f48be_row15_col2, #T_f48be_row16_col0, #T_f48be_row16_col2, #T_f48be_row17_col0, #T_f48be_row17_col2 {
#   background-color: #DC143C;
# }
# #T_f48be_row0_col1, #T_f48be_row0_col3, #T_f48be_row1_col1, #T_f48be_row1_col3, #T_f48be_row2_col1, #T_f48be_row2_col3, #T_f48be_row3_col1, #T_f48be_row3_col2, #T_f48be_row4_col1, #T_f48be_row4_col2, #T_f48be_row5_col1, #T_f48be_row5_col3, #T_f48be_row6_col1, #T_f48be_row6_col3, #T_f48be_row7_col1, #T_f48be_row7_col2, #T_f48be_row8_col1, #T_f48be_row8_col3, #T_f48be_row9_col1, #T_f48be_row9_col3, #T_f48be_row10_col1, #T_f48be_row10_col3, #T_f48be_row11_col1, #T_f48be_row11_col3, #T_f48be_row12_col1, #T_f48be_row12_col2, #T_f48be_row13_col1, #T_f48be_row13_col3, #T_f48be_row14_col1, #T_f48be_row14_col3, #T_f48be_row15_col1, #T_f48be_row15_col3, #T_f48be_row16_col1, #T_f48be_row16_col3, #T_f48be_row17_col1, #T_f48be_row17_col3 {
#   background-color: #228B22;
# }
# </style>
# <table id="T_f48be">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >supervise_mode</th>
#       <th id="T_f48be_level0_col0" class="col_heading level0 col0" colspan="2">real-anomaly</th>
#       <th id="T_f48be_level0_col2" class="col_heading level0 col2" colspan="2">synthetic-anomaly-confetti</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >loss</th>
#       <th id="T_f48be_level1_col0" class="col_heading level1 col0" >old-fcdd</th>
#       <th id="T_f48be_level1_col1" class="col_heading level1 col1" >pixelwise-batch-avg</th>
#       <th id="T_f48be_level1_col2" class="col_heading level1 col2" >old-fcdd</th>
#       <th id="T_f48be_level1_col3" class="col_heading level1 col3" >pixelwise-batch-avg</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >scheduler_parameters</th>
#       <th id="T_f48be_level2_col0" class="col_heading level2 col0" >higher decay</th>
#       <th id="T_f48be_level2_col1" class="col_heading level2 col1" >higher decay</th>
#       <th id="T_f48be_level2_col2" class="col_heading level2 col2" >higher decay</th>
#       <th id="T_f48be_level2_col3" class="col_heading level2 col3" >higher decay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mvtec_class_type</th>
#       <th class="index_name level1" >normal_class_fullqualified</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f48be_level0_row0" class="row_heading level0 row0" rowspan="10">object</th>
#       <th id="T_f48be_level1_row0" class="row_heading level1 row0" >mvtec_00_bottle</th>
#       <td id="T_f48be_row0_col0" class="data row0 col0" >50.1 (13.3) [45.8]</td>
#       <td id="T_f48be_row0_col1" class="data row0 col1" >68.1 (6.1) [66.3]</td>
#       <td id="T_f48be_row0_col2" class="data row0 col2" >36.0 (6.3) [32.6]</td>
#       <td id="T_f48be_row0_col3" class="data row0 col3" >37.6 (3.4) [39.7]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row1" class="row_heading level1 row1" >mvtec_01_cable</th>
#       <td id="T_f48be_row1_col0" class="data row1 col0" >44.4 (3.2) [43.6]</td>
#       <td id="T_f48be_row1_col1" class="data row1 col1" >57.3 (1.9) [56.1]</td>
#       <td id="T_f48be_row1_col2" class="data row1 col2" >43.6 (0.8) [43.4]</td>
#       <td id="T_f48be_row1_col3" class="data row1 col3" >46.0 (7.7) [46.0]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row2" class="row_heading level1 row2" >mvtec_02_capsule</th>
#       <td id="T_f48be_row2_col0" class="data row2 col0" >6.4 (2.2) [7.0]</td>
#       <td id="T_f48be_row2_col1" class="data row2 col1" >13.5 (9.4) [14.0]</td>
#       <td id="T_f48be_row2_col2" class="data row2 col2" >7.9 (1.6) [8.5]</td>
#       <td id="T_f48be_row2_col3" class="data row2 col3" >12.4 (1.8) [14.8]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row3" class="row_heading level1 row3" >mvtec_05_hazelnut</th>
#       <td id="T_f48be_row3_col0" class="data row3 col0" >38.4 (6.5) [38.5]</td>
#       <td id="T_f48be_row3_col1" class="data row3 col1" >46.5 (10.1) [48.4]</td>
#       <td id="T_f48be_row3_col2" class="data row3 col2" >29.7 (3.0) [30.4]</td>
#       <td id="T_f48be_row3_col3" class="data row3 col3" >21.8 (3.0) [25.2]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row4" class="row_heading level1 row4" >mvtec_07_metal_nut</th>
#       <td id="T_f48be_row4_col0" class="data row4 col0" >88.9 (0.4) [85.6]</td>
#       <td id="T_f48be_row4_col1" class="data row4 col1" >91.2 (1.2) [90.2]</td>
#       <td id="T_f48be_row4_col2" class="data row4 col2" >16.5 (2.7) [16.5]</td>
#       <td id="T_f48be_row4_col3" class="data row4 col3" >11.7 (1.9) [12.7]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row5" class="row_heading level1 row5" >mvtec_08_pill</th>
#       <td id="T_f48be_row5_col0" class="data row5 col0" >60.8 (12.9) [59.6]</td>
#       <td id="T_f48be_row5_col1" class="data row5 col1" >74.3 (5.0) [73.3]</td>
#       <td id="T_f48be_row5_col2" class="data row5 col2" >2.1 (0.1) [2.4]</td>
#       <td id="T_f48be_row5_col3" class="data row5 col3" >2.3 (0.2) [2.3]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row6" class="row_heading level1 row6" >mvtec_09_screw</th>
#       <td id="T_f48be_row6_col0" class="data row6 col0" >0.9 (0.2) [1.6]</td>
#       <td id="T_f48be_row6_col1" class="data row6 col1" >5.1 (2.3) [8.2]</td>
#       <td id="T_f48be_row6_col2" class="data row6 col2" >0.9 (0.2) [1.7]</td>
#       <td id="T_f48be_row6_col3" class="data row6 col3" >1.0 (0.2) [2.1]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row7" class="row_heading level1 row7" >mvtec_11_toothbrush</th>
#       <td id="T_f48be_row7_col0" class="data row7 col0" >15.9 (18.3) [15.4]</td>
#       <td id="T_f48be_row7_col1" class="data row7 col1" >26.0 (15.2) [27.2]</td>
#       <td id="T_f48be_row7_col2" class="data row7 col2" >6.3 (6.1) [7.1]</td>
#       <td id="T_f48be_row7_col3" class="data row7 col3" >3.0 (1.0) [4.3]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row8" class="row_heading level1 row8" >mvtec_12_transistor</th>
#       <td id="T_f48be_row8_col0" class="data row8 col0" >31.8 (3.6) [30.8]</td>
#       <td id="T_f48be_row8_col1" class="data row8 col1" >35.4 (4.5) [33.7]</td>
#       <td id="T_f48be_row8_col2" class="data row8 col2" >24.4 (6.2) [22.5]</td>
#       <td id="T_f48be_row8_col3" class="data row8 col3" >35.2 (1.4) [35.4]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level1_row9" class="row_heading level1 row9" >mvtec_14_zipper</th>
#       <td id="T_f48be_row9_col0" class="data row9 col0" >14.6 (7.2) [14.1]</td>
#       <td id="T_f48be_row9_col1" class="data row9 col1" >64.4 (1.6) [59.8]</td>
#       <td id="T_f48be_row9_col2" class="data row9 col2" >7.4 (5.3) [7.4]</td>
#       <td id="T_f48be_row9_col3" class="data row9 col3" >30.6 (3.8) [29.4]</td>
#     </tr>
#     <tr>
#       <th id="T_f48be_level0_row10" class="row_heading level0 row10" rowspan="5">texture</th>
#       <th id="T_f48be_level1_row10" class="row_heading level1 row10" >mvtec_03_carpet</th>
#       <td id="T_f48be_row10_col0" class="data row10 col0" >69.0 (3.4) [66.5]</td>
#       <td id="T_f48be_row10_col1" class="data row10 col1" >73.6 (1.9) [73.6]</td>
#       <td id="T_f48be_row10_col2" class="data row10 col2" >38.1 (5.9) [37.1]</td>
#       <td id="T_f48be_

# %% [markdown]
# ## equiv. decay

# %%
pt = pt_composed.loc[:, (slice(None), slice(None), "equiv. decay")].copy()
pt_color_from = pt_test_avg.loc[:, (slice(None), slice(None), "equiv. decay")].copy()
color_mask = get_color_mask_compare_by_line_every_n_cols(pt_color_from, n=2)
pt.style.apply(color_from_mask(color_mask), axis=None)
# Out:
# <style type="text/css">
# #T_0a164_row0_col0, #T_0a164_row0_col3, #T_0a164_row1_col0, #T_0a164_row1_col2, #T_0a164_row2_col0, #T_0a164_row2_col3, #T_0a164_row3_col0, #T_0a164_row3_col2, #T_0a164_row4_col0, #T_0a164_row4_col3, #T_0a164_row5_col1, #T_0a164_row5_col2, #T_0a164_row6_col0, #T_0a164_row6_col3, #T_0a164_row7_col1, #T_0a164_row7_col2, #T_0a164_row8_col1, #T_0a164_row8_col3, #T_0a164_row9_col1, #T_0a164_row9_col3, #T_0a164_row10_col1, #T_0a164_row10_col2, #T_0a164_row11_col0, #T_0a164_row11_col2, #T_0a164_row12_col1, #T_0a164_row12_col2, #T_0a164_row13_col0, #T_0a164_row13_col3, #T_0a164_row14_col1, #T_0a164_row14_col3, #T_0a164_row15_col0, #T_0a164_row15_col3, #T_0a164_row16_col1, #T_0a164_row16_col3, #T_0a164_row17_col0, #T_0a164_row17_col3 {
#   background-color: #DC143C;
# }
# #T_0a164_row0_col1, #T_0a164_row0_col2, #T_0a164_row1_col1, #T_0a164_row1_col3, #T_0a164_row2_col1, #T_0a164_row2_col2, #T_0a164_row3_col1, #T_0a164_row3_col3, #T_0a164_row4_col1, #T_0a164_row4_col2, #T_0a164_row5_col0, #T_0a164_row5_col3, #T_0a164_row6_col1, #T_0a164_row6_col2, #T_0a164_row7_col0, #T_0a164_row7_col3, #T_0a164_row8_col0, #T_0a164_row8_col2, #T_0a164_row9_col0, #T_0a164_row9_col2, #T_0a164_row10_col0, #T_0a164_row10_col3, #T_0a164_row11_col1, #T_0a164_row11_col3, #T_0a164_row12_col0, #T_0a164_row12_col3, #T_0a164_row13_col1, #T_0a164_row13_col2, #T_0a164_row14_col0, #T_0a164_row14_col2, #T_0a164_row15_col1, #T_0a164_row15_col2, #T_0a164_row16_col0, #T_0a164_row16_col2, #T_0a164_row17_col1, #T_0a164_row17_col2 {
#   background-color: #228B22;
# }
# </style>
# <table id="T_0a164">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >supervise_mode</th>
#       <th id="T_0a164_level0_col0" class="col_heading level0 col0" colspan="2">real-anomaly</th>
#       <th id="T_0a164_level0_col2" class="col_heading level0 col2" colspan="2">synthetic-anomaly-confetti</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >loss</th>
#       <th id="T_0a164_level1_col0" class="col_heading level1 col0" >old-fcdd</th>
#       <th id="T_0a164_level1_col1" class="col_heading level1 col1" >pixelwise-batch-avg</th>
#       <th id="T_0a164_level1_col2" class="col_heading level1 col2" >old-fcdd</th>
#       <th id="T_0a164_level1_col3" class="col_heading level1 col3" >pixelwise-batch-avg</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >scheduler_parameters</th>
#       <th id="T_0a164_level2_col0" class="col_heading level2 col0" >equiv. decay</th>
#       <th id="T_0a164_level2_col1" class="col_heading level2 col1" >equiv. decay</th>
#       <th id="T_0a164_level2_col2" class="col_heading level2 col2" >equiv. decay</th>
#       <th id="T_0a164_level2_col3" class="col_heading level2 col3" >equiv. decay</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mvtec_class_type</th>
#       <th class="index_name level1" >normal_class_fullqualified</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a164_level0_row0" class="row_heading level0 row0" rowspan="10">object</th>
#       <th id="T_0a164_level1_row0" class="row_heading level1 row0" >mvtec_00_bottle</th>
#       <td id="T_0a164_row0_col0" class="data row0 col0" >65.3 (8.0) [56.7]</td>
#       <td id="T_0a164_row0_col1" class="data row0 col1" >67.3 (5.4) [65.5]</td>
#       <td id="T_0a164_row0_col2" class="data row0 col2" >25.3 (2.5) [30.1]</td>
#       <td id="T_0a164_row0_col3" class="data row0 col3" >18.0 (0.5) [24.5]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row1" class="row_heading level1 row1" >mvtec_01_cable</th>
#       <td id="T_0a164_row1_col0" class="data row1 col0" >57.4 (2.4) [51.6]</td>
#       <td id="T_0a164_row1_col1" class="data row1 col1" >57.9 (4.0) [57.7]</td>
#       <td id="T_0a164_row1_col2" class="data row1 col2" >48.6 (2.2) [46.1]</td>
#       <td id="T_0a164_row1_col3" class="data row1 col3" >53.1 (2.6) [50.7]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row2" class="row_heading level1 row2" >mvtec_02_capsule</th>
#       <td id="T_0a164_row2_col0" class="data row2 col0" >7.7 (5.5) [7.5]</td>
#       <td id="T_0a164_row2_col1" class="data row2 col1" >24.7 (11.5) [23.7]</td>
#       <td id="T_0a164_row2_col2" class="data row2 col2" >12.7 (2.1) [11.7]</td>
#       <td id="T_0a164_row2_col3" class="data row2 col3" >9.3 (0.6) [12.7]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row3" class="row_heading level1 row3" >mvtec_05_hazelnut</th>
#       <td id="T_0a164_row3_col0" class="data row3 col0" >43.5 (10.9) [41.6]</td>
#       <td id="T_0a164_row3_col1" class="data row3 col1" >50.7 (7.7) [51.3]</td>
#       <td id="T_0a164_row3_col2" class="data row3 col2" >13.3 (1.8) [20.8]</td>
#       <td id="T_0a164_row3_col3" class="data row3 col3" >13.9 (2.1) [19.0]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row4" class="row_heading level1 row4" >mvtec_07_metal_nut</th>
#       <td id="T_0a164_row4_col0" class="data row4 col0" >86.1 (3.2) [86.7]</td>
#       <td id="T_0a164_row4_col1" class="data row4 col1" >86.1 (2.0) [87.5]</td>
#       <td id="T_0a164_row4_col2" class="data row4 col2" >11.5 (2.2) [12.2]</td>
#       <td id="T_0a164_row4_col3" class="data row4 col3" >10.4 (0.3) [11.3]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row5" class="row_heading level1 row5" >mvtec_08_pill</th>
#       <td id="T_0a164_row5_col0" class="data row5 col0" >66.6 (8.4) [64.1]</td>
#       <td id="T_0a164_row5_col1" class="data row5 col1" >64.8 (8.7) [66.8]</td>
#       <td id="T_0a164_row5_col2" class="data row5 col2" >2.2 (0.0) [3.6]</td>
#       <td id="T_0a164_row5_col3" class="data row5 col3" >2.4 (0.0) [2.4]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row6" class="row_heading level1 row6" >mvtec_09_screw</th>
#       <td id="T_0a164_row6_col0" class="data row6 col0" >3.4 (2.3) [3.8]</td>
#       <td id="T_0a164_row6_col1" class="data row6 col1" >6.4 (1.3) [9.6]</td>
#       <td id="T_0a164_row6_col2" class="data row6 col2" >0.7 (0.1) [1.3]</td>
#       <td id="T_0a164_row6_col3" class="data row6 col3" >0.5 (0.2) [1.6]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row7" class="row_heading level1 row7" >mvtec_11_toothbrush</th>
#       <td id="T_0a164_row7_col0" class="data row7 col0" >17.1 (15.9) [16.7]</td>
#       <td id="T_0a164_row7_col1" class="data row7 col1" >15.6 (7.5) [16.6]</td>
#       <td id="T_0a164_row7_col2" class="data row7 col2" >1.5 (0.5) [2.9]</td>
#       <td id="T_0a164_row7_col3" class="data row7 col3" >2.6 (0.4) [3.3]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row8" class="row_heading level1 row8" >mvtec_12_transistor</th>
#       <td id="T_0a164_row8_col0" class="data row8 col0" >50.8 (4.4) [39.8]</td>
#       <td id="T_0a164_row8_col1" class="data row8 col1" >49.9 (4.1) [45.9]</td>
#       <td id="T_0a164_row8_col2" class="data row8 col2" >39.2 (1.7) [35.5]</td>
#       <td id="T_0a164_row8_col3" class="data row8 col3" >30.8 (0.7) [32.2]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level1_row9" class="row_heading level1 row9" >mvtec_14_zipper</th>
#       <td id="T_0a164_row9_col0" class="data row9 col0" >64.9 (3.1) [47.2]</td>
#       <td id="T_0a164_row9_col1" class="data row9 col1" >63.2 (2.9) [60.1]</td>
#       <td id="T_0a164_row9_col2" class="data row9 col2" >30.5 (3.1) [28.6]</td>
#       <td id="T_0a164_row9_col3" class="data row9 col3" >27.4 (3.3) [31.2]</td>
#     </tr>
#     <tr>
#       <th id="T_0a164_level0_row10" class="row_heading level0 row10" rowspan="5">texture</th>
#       <th id="T_0a164_level1_row10" class="row_heading level1 row10" >mvtec_03_carpet</th>
#       <td id="T_0a164_row10_col0" class="data row10 col0" >72.9 (1.5) [71.1]</td>
#       <td id="T_0a164_row10_col1" class="data row10 col1" >71.6 (3.7) [71.2]</td>
#       <td id="T_0a164_row10_col2" class="data row10 col2" >37.6 (0.7) [41.5]</td>
#       <td id="T_0a164
